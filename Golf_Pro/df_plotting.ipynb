# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\prsullins\\OneDrive - Creative Manufacturing, LLC\\ALM.SWE\\DGMD-14\\golf-edit.csv")

# %%
df_2 = df[["class","x13","y15","x24", "x28","y29","x26","x25", "Frame"]]
df_am = df_2[(df_2["class"] == "Amateur")]
pro = df_2[(df_2["class"] == "Pro")]

# %%
#right-shoulder
df_am.plot(kind="scatter", x="Frame", y="x13", s=[2])
pro.plot(kind="scatter", c="r", x="Frame", y="x13", s=[2])
# Out:
# <AxesSubplot:xlabel='Frame', ylabel='x13'>

# %%
#left ankle
df_am.plot(kind="scatter", x="Frame", y="y29", s=[2] )
pro.plot(kind="scatter",  x="Frame", y="y29", s=[2])
# Out:
# <AxesSubplot:xlabel='Frame', ylabel='y29'>

# %%
#r_elbow
df_am.plot(kind="scatter", x="Frame", y="y15", s=[2])
pro.plot(kind="scatter",  x="Frame", y="y15", s=[2])
# Out:
# <AxesSubplot:xlabel='Frame', ylabel='y15'>

# %%
#LEFT ANKLE
df_am.plot(kind="scatter", x="Frame", y="x28", s=[2])
pro.plot(kind="scatter",  x="Frame", y="x28", s=[2])
# Out:
# <AxesSubplot:xlabel='Frame', ylabel='x28'>

# %%
#LEFT_HEEL
df_am.plot(kind="scatter", x="Frame", y="y30", s=[2])
pro.plot(kind="scatter",  x="Frame", y="y30", s=[2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\prsullins\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'y30'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-fd0d6c4ce851> in <module>
#       1 #LEFT_HEEL
# ----> 2 df_am.plot(kind="scatter", x="Frame", y="y30", s=[2])
#       3 pro.plot(kind="scatter",  x="Frame", y="y30", s=[2])
#       4
#
# c:\users\prsullins\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     892         if kind in self._dataframe_kinds:
#     893             if isinstance(data, ABCDataFrame):
# --> 894                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     895             else:
#     896                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# c:\users\prsullins\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# c:\users\prsullins\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     269         self._compute_plot_data()
#     270         self._setup_subplots()
# --> 271         self._make_plot()
#     272         self._add_table()
#     273         self._make_legend()
#
# c:\users\prsullins\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1010         scatter = ax.scatter(
#    1011             data[x].values,
# -> 1012             data[y].values,
#    1013             c=c_values,
#    1014             label=label,
#
# c:\users\prsullins\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# c:\users\prsullins\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'y30'

# %%
#LEFT_KNEE
df_am.plot(kind="scatter", x="Frame", y="x26", s=[2])
pro.plot(kind="scatter",  x="Frame", y="x26", s=[2])

# %%
df_am.plot(kind="scatter", x="Frame", y="x25", s=[2])
pro.plot(kind="scatter",  x="Frame", y="x25", s=[2])
